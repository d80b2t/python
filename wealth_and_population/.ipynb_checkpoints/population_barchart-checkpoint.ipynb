# %%
'''
https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)
http://www.gregreda.com/2013/10/26/working-with-pandas-dataframes/
http://hamelg.blogspot.co.uk/2015/11/python-for-data-analysis-part-19.html
'''
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt

import seaborn

# %%
cols = ['Rank', 'Country', 'UN_Continental_region', 'UN_Statistical_region', 
        'Population', 'Population2015', 'percent_change']

# %%
pop_list = pd.read_table('country.dat', names=cols)

# %%
#print(type(pop_list))
#pop_list.head()
#pop_list.dtypes
#pop_list.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 7 columns):
# Rank                     234 non-null int64
# Country                  234 non-null object
# UN_Continental_region    234 non-null object
# UN_Statistical_region    234 non-null object
# Population               234 non-null object
# Population2015           234 non-null object
# percent_change           234 non-null object
# dtypes: int64(1), object(6)
# memory usage: 12.9+ KB
# Rank                      int64
# Country                  object
# UN_Continental_region    object
# UN_Statistical_region    object
# Population               object
# Population2015           object
# percent_change           object
# dtype: object

# %%
plt.style.use('ggplot')
#plt.style.use('fivethirtyeight')

# %%
## http://pandas.pydata.org/pandas-docs/stable/visualization.html#histograms
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])
#df4.plot.hist(alpha=0.5)

# %%
plt.figure();

# %%
a = pop_list.plot.hist(alpha=0.5)
print(a, type(a))
plt.show()
# Out:
# Axes(0.125,0.125;0.775x0.755) <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
pop_list.plot.hist(['Population'],alpha=0.5)
print(b, type(b))
plt.show()
# Out:
# Axes(0.125,0.125;0.775x0.755) <class 'matplotlib.axes._subplots.AxesSubplot'>

# %%
#diamonds.hist(column="carat",        # Column to plot
 #             figsize=(8,8),         # Plot size
  #            color="blue") 
pop_list = pop_list('Population').astype(np.float)
#x_train = x_train.astype(np.float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-bcdcc55f6e89> in <module>()
#       2  #             figsize=(8,8),         # Plot size
#       3   #            color="blue")
# ----> 4 pop_list = pop_list('Population').astype(np.float)
#       5 #x_train = x_train.astype(np.float)
#
# TypeError: 'DataFrame' object is not callable

# %%
pop_list.plot.hist(column="Population",alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-39eb67865092> in <module>()
# ----> 1 pop_list.plot.hist(column="Population",alpha=0.5)
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/pandas/tools/plotting.py in hist(self, by, bins, **kwds)
#    3870         axes : matplotlib.AxesSubplot or np.array of them
#    3871         """
# -> 3872         return self(kind='hist', by=by, bins=bins, **kwds)
#    3873
#    3874     def kde(self, **kwds):
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/pandas/tools/plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/pandas/tools/plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2641                  yerr=yerr, xerr=xerr,
#    2642                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2643                  **kwds)
#    2644
#    2645
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2468         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2469
# -> 2470     plot_obj.generate()
#    2471     plot_obj.draw()
#    2472     return plot_obj.result
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/pandas/tools/plotting.py in generate(self)
#    1041         self._compute_plot_data()
#    1042         self._setup_subplots()
# -> 1043         self._make_plot()
#    1044         self._add_table()
#    1045         self._make_legend()
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/pandas/tools/plotting.py in _make_plot(self)
#    2099             kwds = self._make_plot_keywords(kwds, y)
#    2100             artists = self._plot(ax, y, column_num=i,
# -> 2101                                  stacking_id=stacking_id, **kwds)
#    2102             self._add_legend_handle(artists[0], label, index=i)
#    2103
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/pandas/tools/plotting.py in _plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#    2077             cls._get_stacked_values(ax, stacking_id, base, kwds['label'])
#    2078         # ignore style
# -> 2079         n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#    2080         cls._update_stacker(ax, stacking_id, n)
#    2081         return patches
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6384             if patch:
#    6385                 p = patch[0]
# -> 6386                 p.update(kwargs)
#    6387                 if lbl is not None:
#    6388                     p.set_label(lbl)
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/matplotlib/artist.py in update(self, props)
#     883         try:
#     884             ret = [_update_property(self, k, v)
# --> 885                    for k, v in props.items()]
#     886         finally:
#     887             self.eventson = store
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     883         try:
#     884             ret = [_update_property(self, k, v)
# --> 885                    for k, v in props.items()]
#     886         finally:
#     887             self.eventson = store
#
# /Users/npr1/astroconda/lib/python3.5/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     876                 func = getattr(self, 'set_' + k, None)
#     877                 if func is None or not six.callable(func):
# --> 878                     raise AttributeError('Unknown property %s' % k)
#     879                 return func(v)
#     880
#
# AttributeError: Unknown property column

# %%
c = pop_list('Population').plot.hist(alpha=0.5)
print(cc, type(c))

# %%
print(a)
print(b)
print(c)

# %%
plt.show()
