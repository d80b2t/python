# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import pandas as pd

# %%
plt.style.use('ggplot')

# %%
# Data in...
#cols= ["Season", "Average Attendance", "Max Attendance", "Min Attendance", "Num Games"]
#data = pd.read_html('Hibs_Home_Attendence.dat',header=None, names=cols)
#data = pd.read_html('Hibs_Home_Attendence_justNums.dat')
data = pd.read_html('Hibs_Home_Attendence_justNums.dat', header=0)[0]
data.head()
# Out:
#       Season  Average Attendance  Max Attendance  Min Attendance  NumGames
# 0  2016/2017               15111           18786           13861        15
# 1  2015/2016                9291           14412            6686        17
# 2  2014/2015               10170           15261            7857        18
# 3  2013/2014               11028           20106            8277        20
# 4  2012/2013               10489           16805            8121        19

# %%
data.plot('Season','Average Attendance')

# %%
plt.show()

# %%
df = data[0]
df.head()

# %%
##http://stackoverflow.com/questions/21961360/matplotlib-plot-datetime-in-pandas-dataframe

# %%
print(df[0][0])
print(type(df[0][0]))

# %%
print(df[0][1])
print(type(df[0][1]))

# %%
print(type(df[0][1:]))
#print(df[0][1:])
year = df[0][1:]
print(len(year))

# %%
print(df[1][0])
print(type(df[1][0]))

# %%
print(df[1][1])
print(type(df[1][1]))

# %%
print(type(df[1][1:]))
#print(df[1][1:])
attendence_ave = df[1][1:]
print(len(attendence_ave))

# %%
df=df.astype(float)

# %%
df.plot()
