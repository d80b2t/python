# %%
import datetime
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd

# %%
# Data in...
data = pd.read_html('/cos_pc19a_npr/data/Hibs/Hibs_Home_Attendences_justNums_wWW2.dat', header=0)[0]
#data.head()
plt.style.use('seaborn')

# %%
figsize=(16, 8)
fontsize=28
leg='Average for Home League Games'

# %%
#f, ax = plt.subplots()

ax=data.plot('Season','Average Attendance', figsize=(16, 8), fontsize=fontsize*0.9, style='go-',
             label=leg, linewidth=4, markersize=14)

ax.set_ylabel("Attendance", fontsize=fontsize)
ax.set_xlabel("Season", fontsize=fontsize)

plt.legend(prop={'size':fontsize*0.8}, markerfirst=False)
plt.gca().invert_xaxis()

plt.savefig('Hibs_Home_Attendences_temp.png', bbox_inches='tight')
plt.show()

# %%
plt.savefig('Hibs_Home_Attendences_temp.pdf', bbox_inches='tight')
plt.show()
